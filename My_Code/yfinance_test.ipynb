# %%
import yfinance as yf

# %%
gold = yf.Ticker("GOLD")

# %%
gold.info
# Out:
# {'address1': 'Brookfield Place, TD Canada Trust Tower',
#  'address2': 'Suite 3700 161 Bay Street',
#  'city': 'Toronto',
#  'state': 'ON',
#  'zip': 'M5J 2S1',
#  'country': 'Canada',
#  'phone': '416-861-9911',
#  'website': 'https://www.barrick.com',
#  'industry': 'Gold',
#  'industryKey': 'gold',
#  'industryDisp': 'Gold',
#  'sector': 'Basic Materials',
#  'sectorKey': 'basic-materials',
#  'sectorDisp': 'Basic Materials',
# ...

# %%
hist = gold.history(period = "max")
print(hist)
# Out:
#                             Open       High        Low      Close    Volume  \
# Date
# 1985-02-13 00:00:00-05:00   0.00   0.463766   0.412237   0.412237     19680
# 1985-02-14 00:00:00-05:00   0.00   0.463766   0.412237   0.412237     65920
# 1985-02-15 00:00:00-05:00   0.00   0.463766   0.412237   0.412237     31360
# 1985-02-19 00:00:00-05:00   0.00   0.412237   0.412237   0.412237      9120
# 1985-02-20 00:00:00-05:00   0.00   0.412237   0.412237   0.412237     40000
# ...                          ...        ...        ...        ...       ...
# 2024-02-16 00:00:00-05:00  14.58  14.770000  14.490000  14.650000  19353800
# 2024-02-20 00:00:00-05:00  14.79  14.940000  14.620000  14.730000  15448800
# 2024-02-21 00:00:00-05:00  14.73  14.770000  14.500000  14.750000  15165500
# 2024-02-22 00:00:00-05:00  14.61  14.630000  14.360000  14.390000  15444600
# 2024-02-23 00:00:00-05:00  14.46  14.760000  14.370000  14.740000  20988400
#
# ...

# %%
gold.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1985-12-13 00:00:00-05:00    0.00000           0.2
# 1987-07-16 00:00:00-04:00    0.00000           2.0
# 1987-11-23 00:00:00-05:00    0.01250           0.0
# 1988-05-24 00:00:00-04:00    0.01250           0.0
# 1988-11-23 00:00:00-05:00    0.00625           0.0
# ...                              ...           ...
# 2022-11-29 00:00:00-05:00    0.15000           0.0
# 2023-02-27 00:00:00-05:00    0.10000           0.0
# 2023-05-30 00:00:00-04:00    0.10000           0.0
# 2023-08-30 00:00:00-04:00    0.10000           0.0
# 2023-11-29 00:00:00-05:00    0.10000           0.0
#
# [105 rows x 2 columns]

# %%
gold.dividends
# Out:
# Date
# 1987-11-23 00:00:00-05:00    0.01250
# 1988-05-24 00:00:00-04:00    0.01250
# 1988-11-23 00:00:00-05:00    0.00625
# 1989-05-24 00:00:00-04:00    0.01875
# 1989-11-24 00:00:00-05:00    0.01875
#                               ...
# 2022-11-29 00:00:00-05:00    0.15000
# 2023-02-27 00:00:00-05:00    0.10000
# 2023-05-30 00:00:00-04:00    0.10000
# 2023-08-30 00:00:00-04:00    0.10000
# 2023-11-29 00:00:00-05:00    0.10000
# Name: Dividends, Length: 101, dtype: float64
